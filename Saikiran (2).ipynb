# %%
pip install notebook
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# Load the dataset
file_path = r'C:\Users\neera\Downloads\simulated_health_wellness_data.csv'
data = pd.read_csv(file_path)

# Display basic info and first few rows
print(health_data.info())
print(health_data.head())

# Exploratory Data Analysis (EDA)
plt.figure(figsize=(12, 6))

# Histogram of all numeric columns
health_data.hist(bins=20, figsize=(10, 8), color='skyblue')
plt.tight_layout()
plt.show()

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(health_data.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(health_data)

# K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(scaled_data)

# Adding the cluster labels to the original data
health_data['Cluster'] = kmeans_labels

# Silhouette Score
sil_score = silhouette_score(scaled_data, kmeans_labels)
print(f'Silhouette Score: {sil_score}')

# Visualizing Clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Exercise_Time_Min', y='BMI', hue='Cluster', data=health_data, palette='viridis', s=100)
plt.title('Clusters of Patients based on Exercise Time and BMI')
plt.show()

# PCA for Dimensionality Reduction
pca = PCA(n_components=2)
pca_components = pca.fit_transform(scaled_data)

# Visualizing PCA components
plt.figure(figsize=(8, 6))
sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=kmeans_labels, palette='viridis', s=100)
plt.title('PCA of Health Data with Cluster Labels')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# Compare explained variance of PCA components
explained_variance = pca.explained_variance_ratio_
print(f'Explained Variance by PCA Components: {explained_variance}')

# K-Means on PCA-Reduced Data
kmeans_pca = KMeans(n_clusters=3, random_state=42)
kmeans_pca_labels = kmeans_pca.fit_predict(pca_components)

# Silhouette Score after PCA
sil_score_pca = silhouette_score(pca_components, kmeans_pca_labels)
print(f'Silhouette Score after PCA: {sil_score_pca}')

# Visualizing Clusters after PCA
plt.figure(figsize=(8, 6))
sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=kmeans_pca_labels, palette='viridis', s=100)
plt.title('Clusters of Patients after PCA')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12 data = pd.read_csv(file_path)
#      14 # Display basic info and first few rows
# ---> 15 print(health_data.info())
#      16 print(health_data.head())
#      18 # Exploratory Data Analysis (EDA)
#
# NameError: name 'health_data' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# Load the dataset
file_path = r'C:\Users\neera\Downloads\simulated_health_wellness_data.csv'
data = pd.read_csv(file_path)

# Display basic info and first few rows
print(data.info())
print(data.head())

# Exploratory Data Analysis (EDA)
plt.figure(figsize=(12, 6))

# Histogram of all numeric columns
data.hist(bins=20, figsize=(10, 8), color='skyblue')
plt.tight_layout()
plt.show()

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(scaled_data)

# Adding the cluster labels to the original data
data['Cluster'] = kmeans_labels

# Silhouette Score
sil_score = silhouette_score(scaled_data, kmeans_labels)
print(f'Silhouette Score: {sil_score}')

# Visualizing Clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Exercise_Time_Min', y='BMI', hue='Cluster', data=data, palette='viridis', s=100)
plt.title('Clusters of Patients based on Exercise Time and BMI')
plt.show()

# PCA for Dimensionality Reduction
pca = PCA(n_components=2)
pca_components = pca.fit_transform(scaled_data)

# Visualizing PCA components
plt.figure(figsize=(8, 6))
sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=kmeans_labels, palette='viridis', s=100)
plt.title('PCA of Health Data with Cluster Labels')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# Compare explained variance of PCA components
explained_variance = pca.explained_variance_ratio_
print(f'Explained Variance by PCA Components: {explained_variance}')

# K-Means on PCA-Reduced Data
kmeans_pca = KMeans(n_clusters=3, random_state=42)
kmeans_pca_labels = kmeans_pca.fit_predict(pca_components)

# Silhouette Score after PCA
sil_score_pca = silhouette_score(pca_components, kmeans_pca_labels)
print(f'Silhouette Score after PCA: {sil_score_pca}')

# Visualizing Clusters after PCA
plt.figure(figsize=(8, 6))
sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=kmeans_pca_labels, palette='viridis', s=100)
plt.title('Clusters of Patients after PCA')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Exercise_Time_Min      200 non-null    float64
#  1   Healthy_Meals_Per_Day  200 non-null    int64
#  2   Sleep_Hours_Per_Night  200 non-null    float64
#  3   Stress_Level           200 non-null    int64
#  4   BMI                    200 non-null    float64
# dtypes: float64(3), int64(2)
# memory usage: 7.9 KB
# None
#    Exercise_Time_Min  Healthy_Meals_Per_Day  Sleep_Hours_Per_Night  \
# 0          34.967142                      5               7.618856
# 1          28.617357                      8               4.105473
# 2          36.476885                      4               6.024123
# 3          45.230299                      1               8.565319
# 4          27.658466                      3               8.301648
#
#    Stress_Level        BMI
# ...
